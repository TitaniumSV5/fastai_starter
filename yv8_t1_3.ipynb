# %%
import os
# Out:
# /content

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.2/721.2 kB 4.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='https://www.royalenfield.com/node/assets/TripStory/19-03-20-08-03-03_WhatsAppImage2020-03-19at13.31.20.jpeg'
# Out:
# ...
# 100% 83.7M/83.7M [00:00<00:00, 235MB/s]
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 268 layers, 43668288 parameters, 0 gradients, 165.2 GFLOPs
#
# Found https://www.royalenfield.com/node/assets/TripStory/19-03-20-08-03-03_WhatsAppImage2020-03-19at13.31.20.jpeg locally at 19-03-20-08-03-03_WhatsAppImage2020-03-19at13.31.20.jpeg
# image 1/1 /content/19-03-20-08-03-03_WhatsAppImage2020-03-19at13.31.20.jpeg: 480x640 5 persons, 4 motorcycles, 104.8ms
# Speed: 3.7ms preprocess, 104.8ms inference, 536.2ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename='runs/detect/predict4/19-03-20-08-03-03_WhatsAppImage2020-03-19at13.31.20.jpeg', height = 600)

# %%
model = YOLO(f'{HOME}/yolov8n.pt')
results = model.predict(source='https://www.royalenfield.com/node/assets/TripStory/19-03-20-08-03-03_WhatsAppImage2020-03-19at13.31.20.jpeg', conf=0.25)
