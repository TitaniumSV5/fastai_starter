# %% [markdown]
# <a href="https://colab.research.google.com/github/TitaniumSV5/fastai_starter/blob/main/yolo_number_plate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.chdir('/content/drive/MyDrive/Colab_Notebooks')

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16413, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 16413 (delta 0), reused 3 (delta 0), pack-reused 16408
# Receiving objects: 100% (16413/16413), 14.90 MiB | 14.87 MiB/s, done.
# Resolving deltas: 100% (11265/11265), done.

# %%
# !python /content/drive/MyDrive/Colab_Notebooks/yolov5/train.py \
--img 640 \
--batch 16 \
--epochs 100 \
--data /content/drive/MyDrive/Colab_Notebooks/yolov5/data.yaml \
--cfg /content/drive/MyDrive/Colab_Notebooks/yolov5/models/yolov5s.yaml \
--weights '' \
--name plate_detection
# Out:
# 2024-02-13 04:01:22.056446: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-13 04:01:22.056505: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-13 04:01:22.058469: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python yolov5/detect.py --weights yolov5/runs/train/plate_detection9/weights/best.pt --img 640 --conf 0.5 --source yolov5/plates/
# Out:
# detect: weights=['yolov5/runs/train/plate_detection9/weights/best.pt'], source=yolov5/plates/, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-284-g95ebf68f Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/2 /content/drive/MyDrive/Colab_Notebooks/yolov5/plates/0a0d1748-48cd-4114-90cb-b5baf0b3cbe4___3e7fd381-0ae5-4421-8a70-279ee0ec1c61_147274518_15141875973_large_jpg.rf.4542000ba46a0cda0463f08629ad96bf.jpg: 512x640 1 License-Plate, 49.1ms
# ...
